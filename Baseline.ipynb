# %%
import Modules.Data as Data
import numpy as np
import matplotlib.pyplot as plt

max_Heating_power = 300 # in kW
max_HVAC_power = 175 # in kW

COP = 0.95
EER = 3

data_path = "Data/XL-BES-Tool_Output_09-03.csv"
write_path = "Data/Output-Baseline.csv"

heating_demand_array = Data.column_from_csv(data_path, "Heating_thermal_load(kW)") 
heating_demand_array = np.clip(heating_demand_array, 0, max_Heating_power)
boiler_power = heating_demand_array /  COP

cooling_demand_array = Data.column_from_csv(data_path, "Cooling_thermal_load(kW)") 
cooling_demand_array = np.clip(cooling_demand_array, 0, max_HVAC_power)
cooling_electricity = cooling_demand_array / EER

# write to csv
Data.write_to_csv(data_path, write_path, "Energy_Heating(kW)", np.round(boiler_power, decimals=2))
# each column is written individually so second time around read from
# file that was previously written to
Data.write_to_csv(write_path, write_path, "Energy_Cooling(kW)", np.round(cooling_electricity, decimals=2))
